# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.applications.xception import Xception
import segmentation_models as sm
import tensorflow_advanced_segmentation_models as tasm
import numpy as np
import visualkeras

# %% [markdown]
# ## Failed ResNet Test

# %%
resnet = ResNet50(weights="imagenet", include_top=False, input_shape=(512, 512, 3))

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 518, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 256, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 256, 256, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 258, 258, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 128, 128, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 128, 128, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 128, 128, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block2_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 128, 128, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 128, 128, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 128, 128, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 64, 64, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 64, 64, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 64, 64, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 32, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 32, 32, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 32, 32, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 32, 32, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 32, 32, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 16, 16, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 16, 16, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 16, 16, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 16, 16, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 16, 16, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 16, 16, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 16, 16, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
layer_names = ["conv1_pad", "conv1_conv", "conv1_bn", "conv1_relu", "pool1_pad" "pool1_pool"]

resnet_blocks = {"conv7": ["conv1_pad", "conv1_conv", "conv1_bn", "conv1_relu", "pool1_pad", "pool1_pool"],
                 "block_3" : ["conv2_block3_1_conv", "conv2_block3_1_bn", "conv2_block3_1_relu", "conv2_block3_2_conv", "conv2_block3_2_bn", "conv2_block3_2_relu"],
                 "block_4" : ["conv3_block4_1_conv", "conv3_block4_1_bn", "conv3_block4_1_relu", "conv3_block4_2_conv", "conv3_block4_2_bn", "conv3_block4_2_relu"],
                 "block_6" : ["conv4_block6_1_conv", "conv4_block6_1_bn", "conv4_block6_1_relu", "conv4_block6_2_conv", "conv4_block6_2_bn", "conv4_block6_2_relu"],
                 "block_3_2" : ["conv5_block3_1_conv", "conv5_block3_1_bn", "conv5_block3_1_relu", "conv5_block3_2_conv", "conv5_block3_2_bn", "conv5_block3_2_relu"]}

# %%
layers = [resnet.get_layer(layer_name) for layer_name in resnet_blocks["block_3"]]

# %%
x = tf.keras.layers.Input((512, 512, 3))
copy = x
for layer in layers:
    x = layer(x)
#output = tf.keras.layers.Add()([copy, x])

# %%
x.shape
# Out:
# TensorShape([None, 128, 128, 64])

# %%
for layer in layers:
    x = layer(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-d294371235d3> in <module>
#       1 for layer in layers:
# ----> 2     x = layer(x)
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1967   except errors.InvalidArgumentError as e:
#    1968     # Convert to ValueError for backwards compatibility.
# -> 1969     raise ValueError(e.message)
#    1970
#    1971   # Record the current Python stack trace as the creating stacktrace of this
#
# ValueError: Exception encountered when calling layer "conv2_block3_1_conv" (type Conv2D).
#
# Depth of input (64) is not a multiple of input depth of filter (256) for '{{node conv2_block3_1_conv/Conv2D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](Placeholder, conv2_block3_1_conv/Conv2D/ReadVariableOp)' with input shapes: [?,128,128,64], [1,1,256,64].
#
# Call arguments received by layer "conv2_block3_1_conv" (type Conv2D):
#   • inputs=tf.Tensor(shape=(None, 128, 128, 64), dtype=float32)

# %% [markdown]
# ## Xception

# %%
x = Xception(weights="imagenet", input_shape=(512,512, 3), include_top=False)

# %%
x.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 255, 255, 32  864         ['input_18[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 255, 255, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 255, 255, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 253, 253, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 253, 253, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 253, 253, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 253, 253, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 253, 253, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 253, 253, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 253, 253, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 253, 253, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_592 (Conv2D)            (None, 127, 127, 12  8192        ['block1_conv2_act[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 127, 127, 12  0           ['block2_sepconv2_bn[0][0]']
#                                 8)
#
#  batch_normalization_568 (Batch  (None, 127, 127, 12  512        ['conv2d_592[0][0]']
#  Normalization)                 8)
#
#  add_28 (Add)                   (None, 127, 127, 12  0           ['block2_pool[0][0]',
#                                 8)                                'batch_normalization_568[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 127, 127, 12  0          ['add_28[0][0]']
#  n)                             8)
#
#  block3_sepconv1 (SeparableConv  (None, 127, 127, 25  33920      ['block3_sepconv1_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv1_bn (BatchNorma  (None, 127, 127, 25  1024       ['block3_sepconv1[0][0]']
#  lization)                      6)
#
#  block3_sepconv2_act (Activatio  (None, 127, 127, 25  0          ['block3_sepconv1_bn[0][0]']
#  n)                             6)
#
#  block3_sepconv2 (SeparableConv  (None, 127, 127, 25  67840      ['block3_sepconv2_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv2_bn (BatchNorma  (None, 127, 127, 25  1024       ['block3_sepconv2[0][0]']
#  lization)                      6)
#
#  conv2d_593 (Conv2D)            (None, 64, 64, 256)  32768       ['add_28[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 64, 64, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_569 (Batch  (None, 64, 64, 256)  1024       ['conv2d_593[0][0]']
#  Normalization)
#
#  add_29 (Add)                   (None, 64, 64, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_569[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 64, 64, 256)  0          ['add_29[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 64, 64, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 64, 64, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 64, 64, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 64, 64, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 64, 64, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_594 (Conv2D)            (None, 32, 32, 728)  186368      ['add_29[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 32, 32, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_570 (Batch  (None, 32, 32, 728)  2912       ['conv2d_594[0][0]']
#  Normalization)
#
#  add_30 (Add)                   (None, 32, 32, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_570[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_30[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_31 (Add)                   (None, 32, 32, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_30[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_31[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_32 (Add)                   (None, 32, 32, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_31[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_32[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_33 (Add)                   (None, 32, 32, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_32[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_33[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_34 (Add)                   (None, 32, 32, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_33[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_34[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_35 (Add)                   (None, 32, 32, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_34[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_35[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_36 (Add)                   (None, 32, 32, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_35[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_36[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_37 (Add)                   (None, 32, 32, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_36[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_37[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_38 (Add)                   (None, 32, 32, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_37[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_38[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 32, 32, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 32, 32, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_595 (Conv2D)            (None, 16, 16, 1024  745472      ['add_38[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 16, 16, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_571 (Batch  (None, 16, 16, 1024  4096       ['conv2d_595[0][0]']
#  Normalization)                 )
#
#  add_39 (Add)                   (None, 16, 16, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_571[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 16, 16, 1536  1582080    ['add_39[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 16, 16, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 16, 16, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 16, 16, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 16, 16, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 16, 16, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ## VGG U-Net

# %%
vgg19 = VGG19(weights="imagenet", include_top=False, input_shape=(512,512,3))

# %%
visualkeras.layered_view(vgg19).show()

# %%
vgg19.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 512, 512, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 512, 512, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 256, 256, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 256, 256, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 256, 256, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 128, 128, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 128, 128, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_conv4 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 64, 64, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Getting all the blocks from the VGG network
vgg_blocks = {
    f"block{n}" : [layer for layer in vgg19.layers if f"block{n}_conv" in layer.name] for n in range(1, 6)
}

# %%
vgg_blocks
# Out:
# {'block1': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb21ef76990>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21ee66cd0>],
#  'block2': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f429790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f429890>],
#  'block3': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f43a790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f434150>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f434810>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f42f810>],
#  'block4': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4b9950>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4bfd50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4b4a10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4d1990>],
#  'block5': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4d8910>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4b4b10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4d8210>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f4d8950>]}

# %% [markdown]
# ### VGG 1 - Encoder

# %%
def vgg_encoder_block(x, layers):
    """
    This function passes an input through a set of conv layers from VGG19, returning the downsampled and convolved activation
    """
    for layer in layers:
        x = layer(x)
    
    addition = x
    x = tf.keras.layers.MaxPooling2D((2,2), strides = 2)(x)
    return (x, addition)

def last_vgg_block(x, layers):

    for layer in layers:
        x = layer(x)
    
    return x

# %%
input_x = vgg19.input

# %%
input_x
# Out:
# <KerasTensor: shape=(None, 512, 512, 3) dtype=float32 (created by layer 'input_1')>

# %%
block_1 = vgg_encoder_block(input_x, vgg_blocks["block1"])

# %%
block_1
# Out:
# (<KerasTensor: shape=(None, 256, 256, 64) dtype=float32 (created by layer 'max_pooling2d')>,
#  <KerasTensor: shape=(None, 512, 512, 64) dtype=float32 (created by layer 'block1_conv2')>)

# %%
def vgg_encoder_full(input, layer_dict):

    """
    This function creates the full encoder given a dictionary of layers from the VGG network, it returns the final activation 
    and a list of intermediate activations
    """

    activations = []
    x = input
    for layer_name in list(layer_dict.keys())[:-1]:
        x, a = vgg_encoder_block(x, layer_dict[layer_name])
        activations.append(a)
    
    x = last_vgg_block(x, layer_dict[list(layer_dict.keys())[-1]])
    
    return x, activations

# %%
x, a = vgg_encoder_full(input_x, vgg_blocks)

# %%
x
# Out:
# <KerasTensor: shape=(None, 32, 32, 512) dtype=float32 (created by layer 'block5_conv4')>

# %% [markdown]
# ### VGG 2 - Decoder

# %%
def decoder_block(a, x, f):

    x = tf.keras.layers.Conv2DTranspose(filters=f, kernel_size=2, strides=2, padding="same", activation="relu")(x)
    x = tf.concat([a, x], axis=-1)
    x = tf.keras.layers.Conv2D(f, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(f, 3, padding="same", activation="relu")(x) 

    return x

# %%
def decoder_full(activations, x, filters, num_classes):

    for a,f in zip(activations[::-1],filters):
        x = decoder_block(a, x, f)
    
    output = tf.keras.layers.Conv2D(num_classes, 1, padding="same", activation="softmax")(x)

    return output

# %%
filters = [512, 256, 128, 64]
o = decoder_full(a, x, filters, 3)

# %%
o
# Out:
# <KerasTensor: shape=(None, 512, 512, 3) dtype=float32 (created by layer 'conv2d_8')>

# %% [markdown]
# ### VGG 3 - Full U-Net

# %%
def vgg_unet(num_classes, input_size, input_dim):

    #Downloading the VGG network
    vgg19 = VGG19(weights="imagenet", include_top=False, input_shape=(input_size, input_size,input_dim))
    vgg19.trainable = False
    #Getting all the blocks from the VGG network
    vgg_blocks = {
        f"block{n}" : [layer for layer in vgg19.layers if f"block{n}_conv" in layer.name] for n in range(1, 6)
    }
    
    #Filters for the Decoder
    filters = [512, 256, 128, 64]

    vgg_input = vgg19.input

    #Defining the encoder

    #First Preprocess the input
    x = preprocess_input(x=vgg_input)
    
    x, a = vgg_encoder_full(x, vgg_blocks)

    output = decoder_full(a, x, filters, num_classes)

    vgg_unet_model = tf.keras.Model(vgg_input, output)

    return vgg_unet_model

# %%
vnet = vgg_unet(3, 512, 3)

# %%
visualkeras.layered_view(vnet, legend=True, scale_xy=0.5).show()

# %%
vnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  tf.__operators__.getitem (Slic  (None, 512, 512, 3)  0          ['input_2[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)    (None, 512, 512, 3)  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  block1_conv1 (Conv2D)          (None, 512, 512, 64  1792        ['tf.nn.bias_add[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 512, 512, 64  36928       ['block1_conv1[1][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 64  0          ['block1_conv2[1][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 256, 256, 12  73856       ['max_pooling2d_5[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 256, 256, 12  147584      ['block2_conv1[1][0]']
#                                 8)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 12  0          ['block2_conv2[1][0]']
#                                 8)
#
#  block3_conv1 (Conv2D)          (None, 128, 128, 25  295168      ['max_pooling2d_6[0][0]']
#                                 6)
#
#  block3_conv2 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv1[1][0]']
#                                 6)
#
#  block3_conv3 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv2[1][0]']
#                                 6)
#
#  block3_conv4 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv3[1][0]']
#                                 6)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 256)  0          ['block3_conv4[1][0]']
#
#  block4_conv1 (Conv2D)          (None, 64, 64, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv1[1][0]']
#
#  block4_conv3 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv2[1][0]']
#
#  block4_conv4 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv3[1][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 512)  0          ['block4_conv4[1][0]']
#
#  block5_conv1 (Conv2D)          (None, 32, 32, 512)  2359808     ['max_pooling2d_8[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv1[1][0]']
#
#  block5_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv2[1][0]']
#
#  block5_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv3[1][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  1049088    ['block5_conv4[1][0]']
#  spose)
#
#  tf.concat_4 (TFOpLambda)       (None, 64, 64, 1024  0           ['block4_conv4[1][0]',
#                                 )                                 'conv2d_transpose_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 512)  4719104     ['tf.concat_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_9[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['conv2d_10[0][0]']
#  spose)                         6)
#
#  tf.concat_5 (TFOpLambda)       (None, 128, 128, 51  0           ['block3_conv4[1][0]',
#                                 2)                                'conv2d_transpose_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 25  1179904     ['tf.concat_5[0][0]']
#                                 6)
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_11[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['conv2d_12[0][0]']
#  spose)                         8)
#
#  tf.concat_6 (TFOpLambda)       (None, 256, 256, 25  0           ['block2_conv2[1][0]',
#                                 6)                                'conv2d_transpose_6[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 12  295040      ['tf.concat_6[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_13[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['conv2d_14[0][0]']
#  spose)                         )
#
#  tf.concat_7 (TFOpLambda)       (None, 512, 512, 12  0           ['block1_conv2[1][0]',
#                                 8)                                'conv2d_transpose_7[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 512, 512, 64  73792       ['tf.concat_7[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 3)  195         ['conv2d_16[0][0]']
#
# ==================================================================================================
# Total params: 31,164,483
# Trainable params: 11,140,099
# Non-trainable params: 20,024,384
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet-U-Net

# %%
resnet = ResNet50(weights="imagenet", include_top=False, input_shape=(512,512,3))

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 518, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 256, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 256, 256, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 258, 258, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 128, 128, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 128, 128, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 128, 128, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block2_add (Add)         (None, 128, 128, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 128, 128, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 128, 128, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 128, 128, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 128, 128, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 64, 64, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 64, 64, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 64, 64, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 64, 64, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 64, 64, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 64, 64, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 32, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 32, 32, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 32, 32, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 32, 32, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 32, 32, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 32, 32, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 32, 32, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 32, 32, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 32, 32, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 32, 32, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 16, 16, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 16, 16, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 16, 16, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 16, 16, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 16, 16, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 16, 16, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 16, 16, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 16, 16, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 16, 16, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 16, 16, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 16, 16, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 16, 16, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
resnet_blocks = {
    f"block_{n}" : [layer for layer in resnet.layers if layer.name[:5] == f"conv{n}"] for n in range(1, 5)
}

# %%
resnet_outputs = {
    f"output_{n}" : [layer.name for layer in resnet.layers if layer.name[:5] == f"conv{n}" and "out" in layer.name][-1] for n in range(2, 5)
}

# %%
size = 0
for k in resnet_blocks.keys():
    size += len(resnet_blocks[k])
print(f"Number of layers {size}")
# Out:
# Number of layers 140

# %%
su = [1 for layer in resnet.layers]

# %%
sum(su)
# Out:
# 175

# %% [markdown]
# ### Encoder of the ResNet-U-Net

# %%
resnet_blocks
# Out:
# {'block_1': [<keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb216c57c10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f522790>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216c61c10>,
#   <keras.layers.core.activation.Activation at 0x7fb21f7b66d0>],
#  'block_2': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb2224c6750>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2167917d0>,
#   <keras.layers.core.activation.Activation at 0x7fb21678c410>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb2243fc910>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2243e6f90>,
#   <keras.layers.core.activation.Activation at 0x7fb216c52cd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb2167918d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb2224c47d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216791310>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2224db990>,
#   <keras.layers.merging.add.Add at 0x7fb20e256950>,
#   <keras.layers.core.activation.Activation at 0x7fb23d22cd90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb2224c1f90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb21f7581d0>,
#   <keras.layers.core.activation.Activation at 0x7fb216c68f50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb216c68c50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2224c3f50>,
#   <keras.layers.core.activation.Activation at 0x7fb20e256e90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e267650>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e27ad50>,
#   <keras.layers.merging.add.Add at 0x7fb20e267310>,
#   <keras.layers.core.activation.Activation at 0x7fb20e280f10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e267d50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e280250>,
#   <keras.layers.core.activation.Activation at 0x7fb20e262d50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb21f7bd410>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e30fb10>,
#   <keras.layers.core.activation.Activation at 0x7fb2224db290>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e2fd510>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e30fbd0>,
#   <keras.layers.merging.add.Add at 0x7fb20e2770d0>,
#   <keras.layers.core.activation.Activation at 0x7fb20e326ed0>],
#  'block_3': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb2224bb8d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb222456910>,
#   <keras.layers.core.activation.Activation at 0x7fb21676aa90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e30f490>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e256190>,
#   <keras.layers.core.activation.Activation at 0x7fb2224c4e10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e2fd2d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e30a210>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e262e50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216785e50>,
#   <keras.layers.merging.add.Add at 0x7fb20e256690>,
#   <keras.layers.core.activation.Activation at 0x7fb20e317c90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e475110>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e32e0d0>,
#   <keras.layers.core.activation.Activation at 0x7fb20e4695d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e469f90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e489310>,
#   <keras.layers.core.activation.Activation at 0x7fb20e484a50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e46e150>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e489a50>,
#   <keras.layers.merging.add.Add at 0x7fb20e478890>,
#   <keras.layers.core.activation.Activation at 0x7fb20e31ea10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e491b90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e97b450>,
#   <keras.layers.core.activation.Activation at 0x7fb20e4a6e90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e46e650>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2243f1e50>,
#   <keras.layers.core.activation.Activation at 0x7fb20e990410>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb216c56550>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216763ed0>,
#   <keras.layers.merging.add.Add at 0x7fb20e9a00d0>,
#   <keras.layers.core.activation.Activation at 0x7fb20e497a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9a01d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e996990>,
#   <keras.layers.core.activation.Activation at 0x7fb20e987a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9a8fd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e984e10>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9c6090>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e97b4d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e9c1790>,
#   <keras.layers.merging.add.Add at 0x7fb20e9db710>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9dba50>],
#  'block_4': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e984610>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e987510>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9e2750>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e25ded0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e9ced10>,
#   <keras.layers.core.activation.Activation at 0x7fb2224d0c10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9e2b90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9d3cd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e9e2950>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216781e90>,
#   <keras.layers.merging.add.Add at 0x7fb20e484c90>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9c6d10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9bbc50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e484b50>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9d3690>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9bb750>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e9f3890>,
#   <keras.layers.core.activation.Activation at 0x7fb20e497950>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e475b50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eabf7d0>,
#   <keras.layers.merging.add.Add at 0x7fb20e9f3990>,
#   <keras.layers.core.activation.Activation at 0x7fb20e97b910>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20ead40d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eacd2d0>,
#   <keras.layers.core.activation.Activation at 0x7fb20eacd650>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20eae7310>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eae7fd0>,
#   <keras.layers.core.activation.Activation at 0x7fb20eae7810>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20eae7dd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eaf0d50>,
#   <keras.layers.merging.add.Add at 0x7fb20ee87e50>,
#   <keras.layers.core.activation.Activation at 0x7fb20eab96d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20ee87c50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20ee79c90>,
#   <keras.layers.core.activation.Activation at 0x7fb20ee9a050>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20ee93390>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20ee93610>,
#   <keras.layers.core.activation.Activation at 0x7fb20eacd510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20ee7eb90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eea1b50>,
#   <keras.layers.merging.add.Add at 0x7fb21486ea90>,
#   <keras.layers.core.activation.Activation at 0x7fb21486ec50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb214861650>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb214867cd0>,
#   <keras.layers.core.activation.Activation at 0x7fb20ee87050>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20eae0e50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20ee8cbd0>,
#   <keras.layers.core.activation.Activation at 0x7fb20eacd190>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20eae0610>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb2224cd6d0>,
#   <keras.layers.merging.add.Add at 0x7fb20ee79510>,
#   <keras.layers.core.activation.Activation at 0x7fb20e9a0b90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e9e8550>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20e475610>,
#   <keras.layers.core.activation.Activation at 0x7fb20eab97d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20eaf0090>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20eaf5290>,
#   <keras.layers.core.activation.Activation at 0x7fb20ee72190>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20ee790d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb216772810>,
#   <keras.layers.merging.add.Add at 0x7fb20e9f3550>,
#   <keras.layers.core.activation.Activation at 0x7fb20e996490>]}

# %%
def resblock_stem(input, layers):

    x = input
    for layer in layers:

        x = layer(x)
    
    a = x
    x = tf.keras.layers.MaxPool2D(2, 2)(x)

    return x, a


def resblock_enc(inp, layers):

    enc = tf.keras.Model(inputs=resnet.get_layer(layers[0].name).input, outputs=resnet.get_layer(layers[-1].name).output)
    x = enc(inp)
    return x

def resnet_encoder(inp, layer_dict):

    keys = list(layer_dict.keys())

    x, a = resblock_stem(inp, layer_dict[keys[0]])

    activations = [a]
    for block in keys[1:]:
        x = resblock_enc(x, layer_dict[block]) 
        activations.append(x)
    
    return x, [None] + activations[:-1]

# %%
inp = resnet.input

# %%
x, a = resblock_stem(inp, resnet_blocks["block_1"])

# %%
x
# Out:
# <KerasTensor: shape=(None, 128, 128, 64) dtype=float32 (created by layer 'max_pooling2d_9')>

# %%
x2 = resblock_enc(x, resnet_blocks["block_2"])

# %%
x2
# Out:
# <KerasTensor: shape=(None, 128, 128, 256) dtype=float32 (created by layer 'model_1')>

# %%
x, a = resnet_encoder(inp, resnet_blocks)

# %% [markdown]
# ### Decoder for The ResNet-Unet
#
# The last decoder block of this U-Net will not use an activation

# %%
def decoder_block(a, x, f):

    x = tf.keras.layers.Conv2DTranspose(filters=f, kernel_size=2, strides=2, padding="same", activation="relu")(x)
    if a is not  None:
        x = tf.concat([a, x], axis=-1)
    x = tf.keras.layers.Conv2D(f, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(f, 3, padding="same", activation="relu")(x) 

    return x

def decoder_full(activations, x, filters, num_classes):

    for a,f in zip(activations[::-1],filters):
        x = decoder_block(a, x, f)
    
    output = tf.keras.layers.Conv2D(num_classes, 1, padding="same", activation="softmax")(x)

    return output

# %%
filters = [512, 256, 128, 64]

# %%
o = decoder_full(a, x, filters, 5)

# %% [markdown]
# ### Full ResNet-Unet

# %%
def resblock_stem(input, layers):

    x = input
    for layer in layers:

        x = layer(x)
    
    a = x
    x = tf.keras.layers.MaxPool2D((2,2), 2)(x)

    return x, a


def resblock_enc(inp, layers, res):

    enc = tf.keras.Model(inputs=res.get_layer(layers[0].name).input, outputs=res.get_layer(layers[-1].name).output)
    x = enc(inp)
    return x

def resnet_encoder(inp, layer_dict, res):

    keys = list(layer_dict.keys())

    x, a = resblock_stem(inp, layer_dict[keys[0]])

    activations = [a]
    for block in keys[1:]:
        x = resblock_enc(x, layer_dict[block], res) 
        activations.append(x)
    
    return x, [None] + activations[:-1]



def resnet_unet(num_classes, input_size, input_dim):

    #Downloading the ResNet
    resnet = ResNet50(weights="imagenet", include_top=False, input_shape=(input_size,input_size,input_dim))

    layer_dict = resnet_blocks = {
    f"block_{n}" : [layer for layer in resnet.layers if layer.name[:5] == f"conv{n}"] for n in range(1, 5)
    }

    #Freezing the layers of the ResNet
    resnet.trainable = False

    #Building the model
    inp = resnet.input
    x = preprocess_input(x=inp)
    x, a = resnet_encoder(inp, layer_dict, resnet)

    filters = [512, 256, 128, 64]

    output = decoder_full(a, x, filters, num_classes)

    model = tf.keras.Model(inp, output)

    return model

# %%
m = resnet_unet(5, 512, 3)

# %%
visualkeras.layered_view(m, scale_xy=1, legend=True).show()

# %%
m.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 518, 3)  0           ['input_8[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 256, 64  9472        ['conv1_pad[1][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1_conv[1][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 256, 256, 64  0           ['conv1_bn[1][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 128, 128, 64  0          ['conv1_relu[1][0]']
#  )                              )
#
#  model_5 (Functional)           (None, 128, 128, 25  220032      ['max_pooling2d_11[0][0]']
#                                 6)
#
#  model_6 (Functional)           (None, 64, 64, 512)  1230336     ['model_5[0][0]']
#
#  model_7 (Functional)           (None, 32, 32, 1024  7129088     ['model_6[0][0]']
#                                 )
#
#  conv2d_transpose_12 (Conv2DTra  (None, 64, 64, 512)  2097664    ['model_7[0][0]']
#  nspose)
#
#  tf.concat_11 (TFOpLambda)      (None, 64, 64, 1024  0           ['model_6[0][0]',
#                                 )                                 'conv2d_transpose_12[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 512)  4719104     ['tf.concat_11[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_27[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 128, 128, 25  524544     ['conv2d_28[0][0]']
#  nspose)                        6)
#
#  tf.concat_12 (TFOpLambda)      (None, 128, 128, 51  0           ['model_5[0][0]',
#                                 2)                                'conv2d_transpose_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 25  1179904     ['tf.concat_12[0][0]']
#                                 6)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_29[0][0]']
#                                 6)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 256, 256, 12  131200     ['conv2d_30[0][0]']
#  nspose)                        8)
#
#  tf.concat_13 (TFOpLambda)      (None, 256, 256, 19  0           ['conv1_relu[1][0]',
#                                 2)                                'conv2d_transpose_14[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 12  221312      ['tf.concat_13[0][0]']
#                                 8)
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_31[0][0]']
#                                 8)
#
#  conv2d_transpose_15 (Conv2DTra  (None, 512, 512, 64  32832      ['conv2d_32[0][0]']
#  nspose)                        )
#
#  conv2d_33 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_transpose_15[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 512, 512, 5)  325         ['conv2d_34[0][0]']
#
# ==================================================================================================
# Total params: 20,667,397
# Trainable params: 12,078,213
# Non-trainable params: 8,589,184
# __________________________________________________________________________________________________

# %% [markdown]
# ## Efficient-Net

# %%
from tensorflow.keras.applications.efficientnet import EfficientNetB4

# %%
b4 = EfficientNetB4(weights="imagenet", include_top=False, input_shape=(512,512,3))

# %%
b4.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['input_12[0][0]']
#
#  normalization (Normalization)  (None, 512, 512, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 512, 512, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 513, 513, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 256, 256, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 256, 256, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 256, 256, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 256, 256, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 256, 256, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 256, 256, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 256, 256, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 256, 256, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 256, 256, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 256, 256, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 256, 256, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 256, 256, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 256, 256, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 257, 257, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 128, 128, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 128, 128, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 128, 128, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 128, 128, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 32  4608        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 128, 128, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2b_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2b_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2b_dwconv[0][0]']
#  )                              2)
#
#  block2b_activation (Activation  (None, 128, 128, 19  0          ['block2b_bn[0][0]']
#  )                              2)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2b_activation[0][0]',
#                                 2)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 128, 128, 32  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 32  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 128, 128, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2c_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2c_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2c_dwconv[0][0]']
#  )                              2)
#
#  block2c_activation (Activation  (None, 128, 128, 19  0          ['block2c_bn[0][0]']
#  )                              2)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2c_activation[0][0]',
#                                 2)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 128, 128, 32  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 32  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2c_add[0][0]']
#                                 2)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2d_expand_conv[0][0]']
#  ization)                       2)
#
#  block2d_expand_activation (Act  (None, 128, 128, 19  0          ['block2d_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2d_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2d_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2d_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2d_dwconv[0][0]']
#  )                              2)
#
#  block2d_activation (Activation  (None, 128, 128, 19  0          ['block2d_bn[0][0]']
#  )                              2)
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2d_activation[0][0]',
#                                 2)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 128, 128, 32  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 32  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2d_add[0][0]']
#                                 2)
#
#  block3a_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block3a_expand_conv[0][0]']
#  ization)                       2)
#
#  block3a_expand_activation (Act  (None, 128, 128, 19  0          ['block3a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 131, 131, 19  0          ['block3a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 64, 64, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 64, 64, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 64, 64, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 64, 64, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 64, 64, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 64, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 64, 64, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 64, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 64, 64, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 64, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 64, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 64, 64, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 65, 65, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 32, 32, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 32, 32, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 32, 32, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 32, 32, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 32, 32, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 32, 32, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 32, 32, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 32, 32, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 32, 32, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 32, 32, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 32, 32, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 32, 32, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 32, 32, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 32, 32, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 32, 32, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 32, 32, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 32, 32, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 32, 32, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 32, 32, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
# ...
#  block6g_expand_activation (Act  (None, 16, 16, 1632  0          ['block6g_expand_bn[0][0]']
#  ivation)                       )
#
#  block6g_dwconv (DepthwiseConv2  (None, 16, 16, 1632  40800      ['block6g_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6g_bn (BatchNormalization  (None, 16, 16, 1632  6528       ['block6g_dwconv[0][0]']
#  )                              )
#
#  block6g_activation (Activation  (None, 16, 16, 1632  0          ['block6g_bn[0][0]']
#  )                              )
#
#  block6g_se_squeeze (GlobalAver  (None, 1632)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 16, 16, 1632  0           ['block6g_activation[0][0]',
#                                 )                                 'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 16, 16, 272)  443904      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 16, 16, 272)  1088       ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 16, 16, 272)  0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 16, 16, 272)  0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 16, 16, 1632  443904      ['block6g_add[0][0]']
#                                 )
#
#  block6h_expand_bn (BatchNormal  (None, 16, 16, 1632  6528       ['block6h_expand_conv[0][0]']
#  ization)                       )
#
#  block6h_expand_activation (Act  (None, 16, 16, 1632  0          ['block6h_expand_bn[0][0]']
#  ivation)                       )
#
#  block6h_dwconv (DepthwiseConv2  (None, 16, 16, 1632  40800      ['block6h_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6h_bn (BatchNormalization  (None, 16, 16, 1632  6528       ['block6h_dwconv[0][0]']
#  )                              )
#
#  block6h_activation (Activation  (None, 16, 16, 1632  0          ['block6h_bn[0][0]']
#  )                              )
#
#  block6h_se_squeeze (GlobalAver  (None, 1632)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 16, 16, 1632  0           ['block6h_activation[0][0]',
#                                 )                                 'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 16, 16, 272)  443904      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 16, 16, 272)  1088       ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 16, 16, 272)  0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 16, 16, 272)  0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 1632  443904      ['block6h_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 1632  6528       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 1632  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 1632  14688      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 1632  6528       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 1632  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1632)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 1632  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 448)  731136      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 448)  1792       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 2688  1204224     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 2688  10752      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 2688  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 2688  24192      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 2688  10752      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 2688  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2688)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2688)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 112)    301168      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2688)   303744      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 2688  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 448)  1204224     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 448)  1792       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 448)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 448)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 1792  802816      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 1792  7168        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 1792  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 17,673,823
# Trainable params: 17,548,616
# Non-trainable params: 125,207
# __________________________________________________________________________________________________

# %%
effnet_blocks = {}
stem_start = [b4.get_layer("rescaling"), b4.get_layer("normalization"), b4.get_layer("rescaling_1")]
stem_start.extend([layer for layer in b4.layers if layer.name[:4] == "stem"])
effnet_blocks["stem"] = stem_start
effnet_blocks = {**effnet_blocks, **{ 
    f"block_{n}" : [layer for layer in b4.layers if layer.name[:6] == f"block{n}"] for n in range(1, 8)
}}

# %%
effnet_blocks
# Out:
# {'stem': [<keras.layers.preprocessing.image_preprocessing.Rescaling at 0x7fb20127c150>,
#   <keras.layers.preprocessing.normalization.Normalization at 0x7fb1ff09d250>,
#   <keras.layers.preprocessing.image_preprocessing.Rescaling at 0x7fb1fe1ba350>,
#   <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb1ff0b0bd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb20e78b3d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fdffb710>,
#   <keras.layers.core.activation.Activation at 0x7fb20e842290>],
#  'block_1': [<keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1fdf730d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fe0c6110>,
#   <keras.layers.core.activation.Activation at 0x7fb1fdf7f790>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1fdf73310>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1fe0b8fd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fdfa5290>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fe1d0210>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1fe0e4050>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fe0a68d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fe06ca90>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1fdffd690>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fdfc3250>,
#   <keras.layers.core.activation.Activation at 0x7fb1fdffd250>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f060c950>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f060c0d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fdfb34d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fdfe4850>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb20125ea10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb201268750>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb201268b50>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1fdfcc390>,
#   <keras.layers.merging.add.Add at 0x7fb1fe0d3fd0>],
#  'block_2': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fe0d35d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f06069d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1fdffdd90>,
#   <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb1fdfe27d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb216c64b10>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fdffd310>,
#   <keras.layers.core.activation.Activation at 0x7fb20e948b10>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1fe0bf110>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0606bd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fe0e4b50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fdfe3390>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1fdfc3850>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1ff0acf50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0630350>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f064bd50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1fe086750>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0660950>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb21f156c50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0671890>,
#   <keras.layers.core.activation.Activation at 0x7fb1f064b590>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb23d1ede50>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0662710>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0671510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0651950>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f0692890>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fdffd190>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f064bf90>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f06a9c90>,
#   <keras.layers.merging.add.Add at 0x7fb1f06af450>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1fe05b410>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f06bebd0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f06b90d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f06a9350>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f081df50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0646a90>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f0671550>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb20e2bfd90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f081dbd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0633c50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb216c52a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0615c50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb20127b790>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f0629110>,
#   <keras.layers.merging.add.Add at 0x7fb1f0629dd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f06b9290>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0629190>,
#   <keras.layers.core.activation.Activation at 0x7fb1fdfc3ed0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f069a190>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f06b9e90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0681990>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f06815d0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f069a1d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f082f250>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0831dd0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f0846e10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0679290>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f084cd90>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f0932710>,
#   <keras.layers.merging.add.Add at 0x7fb1f093a7d0>],
#  'block_3': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f06a42d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f082f310>,
#   <keras.layers.core.activation.Activation at 0x7fb1f093a190>,
#   <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb1f082f050>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f0955d50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0841050>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0955850>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f096f250>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f082ff90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0967210>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f093a450>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f0947050>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f093aad0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0967790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f092d310>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0967850>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0989e50>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f09ab190>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f09ab310>,
#   <keras.layers.core.activation.Activation at 0x7fb1f09abc90>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f09120d0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0841290>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0633f50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0841b90>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f09abd90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f08198d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0928e10>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f06b9850>,
#   <keras.layers.merging.add.Add at 0x7fb1f09bc850>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f06b9990>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0846dd0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f097e890>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f0973fd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f09c4750>,
#   <keras.layers.core.activation.Activation at 0x7fb1f09cc490>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f1335bd0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f1335850>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1335b50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0951c50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f1349510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0951f90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f132e450>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f135eb10>,
#   <keras.layers.merging.add.Add at 0x7fb1f135e110>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f135eb90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1335990>,
#   <keras.layers.core.activation.Activation at 0x7fb1f136b590>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f1375550>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f135ee90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f09cc350>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f1375f90>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f1325390>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1394690>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f132e050>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f138e790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0947810>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1394950>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f13b2f10>,
#   <keras.layers.merging.add.Add at 0x7fb1f13b2d50>],
#  'block_4': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13b2ed0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f13b2890>,
#   <keras.layers.core.activation.Activation at 0x7fb1f13ce290>,
#   <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb1f1375a10>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f13809d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0846c10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1375310>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f133a850>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f13c5590>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f064bf50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13c5190>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f1356d50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1335110>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f13abe50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13868d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f13e3890>,
#   <keras.layers.core.activation.Activation at 0x7fb1f13df250>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1fe065050>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1510610>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1350090>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f13b8410>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0947a50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1523790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13e3e50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f1521190>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1375750>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1536ad0>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f15be8d0>,
#   <keras.layers.merging.add.Add at 0x7fb1f15c2690>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f15c2410>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f13abd50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f15cf390>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f1523290>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f15dfc10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f150a050>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f150a310>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f15cfa50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f15ed990>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f15d4bd0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f13454d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f092ded0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f15e6850>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f162cb50>,
#   <keras.layers.merging.add.Add at 0x7fb1f162cdd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16900d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1621c90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1615c10>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f16005d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f15c28d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f13d4190>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f152f450>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f13c1f90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13e3d10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f162cad0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f1626c50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1523810>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f160c5d0>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f16a6210>,
#   <keras.layers.merging.add.Add at 0x7fb1f16a6d10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16278d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f162c990>,
#   <keras.layers.core.activation.Activation at 0x7fb1f16a6dd0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f15c2290>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f16c8e50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1781e50>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f1781f90>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f1785110>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16a10d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16b7990>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f151d490>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f15ed190>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f1785f90>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f17b1410>,
#   <keras.layers.merging.add.Add at 0x7fb1f17b6350>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1626250>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f17b1090>,
#   <keras.layers.core.activation.Activation at 0x7fb1f16b4110>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f16ae150>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2856610>,
#   <keras.layers.core.activation.Activation at 0x7fb1f16c28d0>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f284e550>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f16ae850>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f284e3d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f17b6790>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f299b650>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1521dd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2873150>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f29a7510>,
#   <keras.layers.merging.add.Add at 0x7fb1f299bd90>],
#  'block_5': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f284ef10>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f287bb10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1785890>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f16ae990>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f16a1210>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1690250>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f1627e50>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f17a1cd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f17818d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f284e690>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f2856d50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f284e6d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f28730d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29a7a90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f16b4c10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f1794f90>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f286ded0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2a32710>,
#   <keras.layers.core.activation.Activation at 0x7fb1f29c4690>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f29cc910>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f286d210>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29c4250>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16b4c50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f2a64750>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f16b7ad0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f29d2650>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f2aeba10>,
#   <keras.layers.merging.add.Add at 0x7fb1f2a563d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29b0250>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2a40850>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2a4e690>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f2b088d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f29d7bd0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2b08e10>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f2b08cd0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f29ccb10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2aeb0d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2aeb8d0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f2aebd50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2aeb390>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2a6a310>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f2c05890>,
#   <keras.layers.merging.add.Add at 0x7fb1f2c0bd90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c05610>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2b0d6d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f29d23d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f2b0d210>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2bf8750>,
#   <keras.layers.core.activation.Activation at 0x7fb1f29a7a50>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f29a7b50>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f2afa510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f13565d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2a56290>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f2c23e90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f178b150>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2c16f50>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f2c58d10>,
#   <keras.layers.merging.add.Add at 0x7fb1f2c58c10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c58fd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2c589d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2c742d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f2c74e10>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2bff790>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2c74690>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f2c54950>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f2c8d310>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c8d250>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c6e210>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f2c8d190>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2b15e10>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f373e590>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f2b0d810>,
#   <keras.layers.merging.add.Add at 0x7fb1f3756890>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f3756e90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2c583d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f375a550>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f2c86f50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f3884b50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f376d310>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f2c5d1d0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f2c86dd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f3767550>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f376d650>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f3892590>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29a79d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f38ab490>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f3756750>,
#   <keras.layers.merging.add.Add at 0x7fb1f37366d0>],
#  'block_6': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c7d050>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f286da90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2af3450>,
#   <keras.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7fb1f3884150>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f13ceb90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f16c25d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2c13e10>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f2c16110>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f3884090>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f38a3610>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2a64490>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f3767390>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f2c8d2d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2a324d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f399e310>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f17b1a10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2c6a190>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f38a3d50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f3892f90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f39cd690>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f39d9a10>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f38a3510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4210a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f39c0590>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f4220d10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f388c410>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f39c8590>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f423ced0>,
#   <keras.layers.merging.add.Add at 0x7fb1f0021510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f39b52d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f2c7d9d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f423ccd0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f39d9e90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f003af50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f0029390>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f00290d0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f39d9650>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f003a5d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f0029a50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f004ad90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4229050>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f004aed0>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f4217510>,
#   <keras.layers.merging.add.Add at 0x7fb1f4217b50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f42043d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f38b6f50>,
#   <keras.layers.core.activation.Activation at 0x7fb1f2c6ad90>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f0029910>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f0057cd0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f420a310>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f39c8e10>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0029a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f39d4350>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f3892410>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f4217810>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f1183850>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f39d4250>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f11a7450>,
#   <keras.layers.merging.add.Add at 0x7fb1f11aee90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f39d4b90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f11a7cd0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f47c7ed0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f47cb0d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f47df690>,
#   <keras.layers.core.activation.Activation at 0x7fb1f47d3310>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f11a3890>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f0034e10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f11ae7d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f47cb1d0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f47f50d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f11830d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f11ae3d0>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f49f82d0>,
#   <keras.layers.merging.add.Add at 0x7fb1f49fedd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f47c7bd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f47f0650>,
#   <keras.layers.core.activation.Activation at 0x7fb1f49fe7d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f4a11290>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f47d3710>,
#   <keras.layers.core.activation.Activation at 0x7fb1f4a11310>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f4e8aed0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f11ae550>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4a1fa90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f49f8790>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f4a09250>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4ea4e50>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f4ea4150>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f11a7510>,
#   <keras.layers.merging.add.Add at 0x7fb1f11a7710>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f11a7a90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f49ec0d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f49fec90>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f4a17810>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f47f54d0>,
#   <keras.layers.core.activation.Activation at 0x7fb1f11a3e50>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f11a3a90>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f4a17490>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4eb2810>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f4800a50>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f4ec5910>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f423c810>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f4ebcb90>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f5478a90>,
#   <keras.layers.merging.add.Add at 0x7fb1f547ff10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5478610>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5478b90>,
#   <keras.layers.core.activation.Activation at 0x7fb1f5478910>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f4eb23d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f547f490>,
#   <keras.layers.core.activation.Activation at 0x7fb1f5494b90>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f548cad0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f4eb2310>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f58fa490>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f548c410>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f58ece50>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f49fe190>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f54780d0>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f4e9c150>,
#   <keras.layers.merging.add.Add at 0x7fb1f59163d0>],
#  'block_7': [<keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5916d90>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5472c10>,
#   <keras.layers.core.activation.Activation at 0x7fb1f5916a90>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f58e50d0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5a0f950>,
#   <keras.layers.core.activation.Activation at 0x7fb1f5a0f810>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f546cbd0>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f5a13690>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5a1c950>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5a068d0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f5a2de90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5913dd0>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5a2db10>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29b0810>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f4ebc210>,
#   <keras.layers.core.activation.Activation at 0x7fb1f59166d0>,
#   <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D at 0x7fb1f5494750>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5484990>,
#   <keras.layers.core.activation.Activation at 0x7fb1f591c0d0>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fb1f5a3aa90>,
#   <keras.layers.reshaping.reshape.Reshape at 0x7fb1f5a13510>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f5da57d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f29b0cd0>,
#   <keras.layers.merging.multiply.Multiply at 0x7fb1f5daa790>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fb1f58ec590>,
#   <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fb1f5dafc90>,
#   <keras.layers.regularization.dropout.Dropout at 0x7fb1f5dc98d0>,
#   <keras.layers.merging.add.Add at 0x7fb1f5dc9810>]}

# %% [markdown]
# ### Efficient-Net Encoder

# %%
def effnet_stem(input, layers):

    x = input

    for layer in layers:
        x = layer(x)
    
    return x
    
def effblock_enc(inp, layers, model):

    enc = tf.keras.Model(inputs=model.get_layer(layers[0].name).input, outputs=model.get_layer(layers[-1].name).output)
    x = enc(inp)
    return x

def effnet_encoder(inp, layer_dict, model):

    keys = list(layer_dict.keys())

    x = effnet_stem(inp, layer_dict[keys[0]])

    activations = [x]
    for block in keys[1:]:

        x = effblock_enc(x, layer_dict[block], model) 
        if block == "block_1" or block ==  "block_4" or block == "block_6":
            continue
        activations.append(x)
    
    return x, [None] + activations[:-1]

# %% [markdown]
# #### Individual Encoder Tests

# %%
s = effnet_blocks["stem"]

# %%
inp = b4.input
x = effnet_stem(inp, effnet_blocks["stem"])
x
# Out:
# <KerasTensor: shape=(None, 256, 256, 48) dtype=float32 (created by layer 'stem_activation')>

# %%
x = effblock_enc(x, effnet_blocks["block_1"], b4)
x
# Out:
# <KerasTensor: shape=(None, 256, 256, 24) dtype=float32 (created by layer 'model_9')>

# %% [markdown]
# #### Full Encoder Test

# %%
x, a = effnet_encoder(inp, effnet_blocks, b4)

# %%
x
# Out:
# <KerasTensor: shape=(None, 16, 16, 448) dtype=float32 (created by layer 'model_16')>

# %%
a[::-1]
# Out:
# [<KerasTensor: shape=(None, 32, 32, 160) dtype=float32 (created by layer 'model_14')>,
#  <KerasTensor: shape=(None, 64, 64, 56) dtype=float32 (created by layer 'model_12')>,
#  <KerasTensor: shape=(None, 128, 128, 32) dtype=float32 (created by layer 'model_11')>,
#  <KerasTensor: shape=(None, 256, 256, 48) dtype=float32 (created by layer 'stem_activation')>,
#  None]

# %% [markdown]
# ### Efficient-Net U-Net Full

# %%
def effnet_unet(num_classes, input_size, input_dim):

    b4 = EfficientNetB4(weights="imagenet", include_top=False, input_shape=(input_size,input_size,input_dim))

    effnet_blocks_dict = {}
    stem_start = [b4.layers[0], b4.layers[1], b4.layers[2]]
    stem_start.extend([layer for layer in b4.layers if layer.name[:4] == "stem"])
    effnet_blocks_dict["stem"] = stem_start
    effnet_blocks_dict = {**effnet_blocks, **{ 
        f"block_{n}" : [layer for layer in b4.layers if layer.name[:6] == f"block{n}"] for n in range(1, 8)
    }}

    #Freeszing the weights of the model
    b4.trainable = False

    #Encoder of the network
    inp = b4.input
    x = preprocess_input(inp)
    #a not being reversed here because it's reversed in the decoder function
    x, a = effnet_encoder(x, effnet_blocks_dict, b4)

    #Decoder of the network
    filters = [160, 56, 32, 48, 64]
    
    output = decoder_full(a, x, filters, num_classes)

    model  = tf.keras.Model(inp, output)

    return model

# %%
m = effnet_unet(5, 512, 3)

# %%
visualkeras.layered_view(m, scale_xy=1, legend=True).show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
m.summary()
# Out:
# Model: "model_56"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_53 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  tf.__operators__.getitem_1 (Sl  (None, 512, 512, 3)  0          ['input_53[0][0]']
#  icingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['tf.nn.bias_add_1[0][0]']
#
#  normalization (Normalization)  (None, 512, 512, 3)  7           ['rescaling[15][0]']
#
#  rescaling_1 (Rescaling)        (None, 512, 512, 3)  0           ['normalization[15][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 513, 513, 3)  0           ['rescaling_1[15][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 48  1296        ['stem_conv_pad[15][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 48  192         ['stem_conv[15][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 48  0           ['stem_bn[15][0]']
#                                 )
#
#  model_49 (Functional)          (None, 256, 256, 24  4386        ['stem_activation[15][0]']
#                                 )
#
#  model_50 (Functional)          (None, 128, 128, 32  69374       ['model_49[0][0]']
#                                 )
#
#  model_51 (Functional)          (None, 64, 64, 56)   202834      ['model_50[0][0]']
#
#  model_52 (Functional)          (None, 32, 32, 112)  1076026     ['model_51[0][0]']
#
#  model_53 (Functional)          (None, 32, 32, 160)  2330532     ['model_52[0][0]']
#
#  model_54 (Functional)          (None, 16, 16, 272)  8690116     ['model_53[0][0]']
#
#  model_55 (Functional)          (None, 16, 16, 448)  4489076     ['model_54[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 160)  286880     ['model_55[0][0]']
#  ose)
#
#  tf.concat (TFOpLambda)         (None, 32, 32, 320)  0           ['model_53[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 160)  460960      ['tf.concat[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 160)  230560      ['conv2d[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 56)  35896       ['conv2d_1[0][0]']
#  spose)
#
#  tf.concat_1 (TFOpLambda)       (None, 64, 64, 112)  0           ['model_51[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 56)   56504       ['tf.concat_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 56)   28280       ['conv2d_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  7200       ['conv2d_3[0][0]']
#  spose)                         )
#
#  tf.concat_2 (TFOpLambda)       (None, 128, 128, 64  0           ['model_50[0][0]',
#                                 )                                 'conv2d_transpose_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  18464       ['tf.concat_2[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 48  6192       ['conv2d_5[0][0]']
#  spose)                         )
#
#  tf.concat_3 (TFOpLambda)       (None, 256, 256, 96  0           ['stem_activation[15][0]',
#                                 )                                 'conv2d_transpose_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 48  41520       ['tf.concat_3[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 48  20784       ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 512, 512, 64  12352      ['conv2d_7[0][0]']
#  spose)                         )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 64  36928       ['conv2d_transpose_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 64  36928       ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 5)  325         ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 18,152,860
# Trainable params: 1,290,413
# Non-trainable params: 16,862,447
# __________________________________________________________________________________________________

# %% [markdown]
# ## Base U-Net

# %%
def encoder_block(inp,f):

    x = inp

    x = tf.keras.layers.Conv2D(f, 3, 1, padding="same")(x)
    x = tf.keras.layers.Conv2D(f, 3, 1, padding="same")(x)
    a = x
    x = tf.keras.layers.MaxPool2D(2, 2)(x)

    return x,a

def last_encoder(inp, f):

    x = inp

    x = tf.keras.layers.Conv2D(f, 3, 1, padding="same")(x)
    x = tf.keras.layers.Conv2D(f, 3, 1, padding="same")(x)

    return x

# %%
def encoder_unet(inp, filters):

    activations = []

    x = inp
    for f in filters[:-1]:
        x, a = encoder_block(x, f)
        activations.append(a)
    
    x = last_encoder(x, filters[-1])
    return x, activations

# %%
encoder_unet(tf.keras.layers.Input((512, 512, 3)), [64, 128, 256, 512, 1024])
# Out:
# (<KerasTensor: shape=(None, 32, 32, 1024) dtype=float32 (created by layer 'conv2d_111')>,
#  [<KerasTensor: shape=(None, 512, 512, 64) dtype=float32 (created by layer 'conv2d_103')>,
#   <KerasTensor: shape=(None, 256, 256, 128) dtype=float32 (created by layer 'conv2d_105')>,
#   <KerasTensor: shape=(None, 128, 128, 256) dtype=float32 (created by layer 'conv2d_107')>,
#   <KerasTensor: shape=(None, 64, 64, 512) dtype=float32 (created by layer 'conv2d_109')>])

# %%
def unet(num_classes, input_size, input_dim):

    inp = tf.keras.layers.Input((input_size, input_size, input_dim))

    filters = [64, 128, 256, 512, 1024]

    x, a = encoder_unet(inp, filters=filters)

    o = decoder_full(a, x, filters, num_classes)

    model = tf.keras.Model(inp, o)

    return model

# %%
un = unet(3, 512, 3)

# %%
un.summary()
# Out:
# Model: "model_49"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_60 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_112 (Conv2D)            (None, 512, 512, 64  1792        ['input_60[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 512, 512, 64  36928       ['conv2d_112[0][0]']
#                                 )
#
#  max_pooling2d_39 (MaxPooling2D  (None, 256, 256, 64  0          ['conv2d_113[0][0]']
#  )                              )
#
#  conv2d_114 (Conv2D)            (None, 256, 256, 12  73856       ['max_pooling2d_39[0][0]']
#                                 8)
#
#  conv2d_115 (Conv2D)            (None, 256, 256, 12  147584      ['conv2d_114[0][0]']
#                                 8)
#
#  max_pooling2d_40 (MaxPooling2D  (None, 128, 128, 12  0          ['conv2d_115[0][0]']
#  )                              8)
#
#  conv2d_116 (Conv2D)            (None, 128, 128, 25  295168      ['max_pooling2d_40[0][0]']
#                                 6)
#
#  conv2d_117 (Conv2D)            (None, 128, 128, 25  590080      ['conv2d_116[0][0]']
#                                 6)
#
#  max_pooling2d_41 (MaxPooling2D  (None, 64, 64, 256)  0          ['conv2d_117[0][0]']
#  )
#
#  conv2d_118 (Conv2D)            (None, 64, 64, 512)  1180160     ['max_pooling2d_41[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 64, 64, 512)  2359808     ['conv2d_118[0][0]']
#
#  max_pooling2d_42 (MaxPooling2D  (None, 32, 32, 512)  0          ['conv2d_119[0][0]']
#  )
#
#  conv2d_120 (Conv2D)            (None, 32, 32, 1024  4719616     ['max_pooling2d_42[0][0]']
#                                 )
#
#  conv2d_121 (Conv2D)            (None, 32, 32, 1024  9438208     ['conv2d_120[0][0]']
#                                 )
#
#  conv2d_transpose_35 (Conv2DTra  (None, 64, 64, 64)  262208      ['conv2d_121[0][0]']
#  nspose)
#
#  tf.concat_27 (TFOpLambda)      (None, 64, 64, 576)  0           ['conv2d_119[0][0]',
#                                                                   'conv2d_transpose_35[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 64, 64, 64)   331840      ['tf.concat_27[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 64, 64, 64)   36928       ['conv2d_122[0][0]']
#
#  conv2d_transpose_36 (Conv2DTra  (None, 128, 128, 12  32896      ['conv2d_123[0][0]']
#  nspose)                        8)
#
#  tf.concat_28 (TFOpLambda)      (None, 128, 128, 38  0           ['conv2d_117[0][0]',
#                                 4)                                'conv2d_transpose_36[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 128, 128, 12  442496      ['tf.concat_28[0][0]']
#                                 8)
#
#  conv2d_125 (Conv2D)            (None, 128, 128, 12  147584      ['conv2d_124[0][0]']
#                                 8)
#
#  conv2d_transpose_37 (Conv2DTra  (None, 256, 256, 25  131328     ['conv2d_125[0][0]']
#  nspose)                        6)
#
#  tf.concat_29 (TFOpLambda)      (None, 256, 256, 38  0           ['conv2d_115[0][0]',
#                                 4)                                'conv2d_transpose_37[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 256, 256, 25  884992      ['tf.concat_29[0][0]']
#                                 6)
#
#  conv2d_127 (Conv2D)            (None, 256, 256, 25  590080      ['conv2d_126[0][0]']
#                                 6)
#
#  conv2d_transpose_38 (Conv2DTra  (None, 512, 512, 51  524800     ['conv2d_127[0][0]']
#  nspose)                        2)
#
#  tf.concat_30 (TFOpLambda)      (None, 512, 512, 57  0           ['conv2d_113[0][0]',
#                                 6)                                'conv2d_transpose_38[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 512, 512, 51  2654720     ['tf.concat_30[0][0]']
#                                 2)
#
#  conv2d_129 (Conv2D)            (None, 512, 512, 51  2359808     ['conv2d_128[0][0]']
#                                 2)
#
#  conv2d_130 (Conv2D)            (None, 512, 512, 3)  1539        ['conv2d_129[0][0]']
#
# ==================================================================================================
# Total params: 27,244,419
# Trainable params: 27,244,419
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Xception-U-Net - Scrapped

# %%
xception = Xception(weights="imagenet", include_top=False, input_shape=(512,512,3))

# %%
xception.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_61 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 255, 255, 32  864         ['input_61[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 255, 255, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 255, 255, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 253, 253, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 253, 253, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 253, 253, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 253, 253, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 253, 253, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 253, 253, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 253, 253, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 253, 253, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_131 (Conv2D)            (None, 127, 127, 12  8192        ['block1_conv2_act[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 127, 127, 12  0           ['block2_sepconv2_bn[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 127, 127, 12  512        ['conv2d_131[0][0]']
#  alization)                     8)
#
#  add (Add)                      (None, 127, 127, 12  0           ['block2_pool[0][0]',
#                                 8)                                'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 127, 127, 12  0          ['add[0][0]']
#  n)                             8)
#
#  block3_sepconv1 (SeparableConv  (None, 127, 127, 25  33920      ['block3_sepconv1_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv1_bn (BatchNorma  (None, 127, 127, 25  1024       ['block3_sepconv1[0][0]']
#  lization)                      6)
#
#  block3_sepconv2_act (Activatio  (None, 127, 127, 25  0          ['block3_sepconv1_bn[0][0]']
#  n)                             6)
#
#  block3_sepconv2 (SeparableConv  (None, 127, 127, 25  67840      ['block3_sepconv2_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv2_bn (BatchNorma  (None, 127, 127, 25  1024       ['block3_sepconv2[0][0]']
#  lization)                      6)
#
#  conv2d_132 (Conv2D)            (None, 64, 64, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 64, 64, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_132[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 64, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 64, 64, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 64, 64, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 64, 64, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 64, 64, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 64, 64, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 64, 64, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_133 (Conv2D)            (None, 32, 32, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 32, 32, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 728)  2912       ['conv2d_133[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 32, 32, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 32, 32, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 32, 32, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 32, 32, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 32, 32, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 32, 32, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 32, 32, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 32, 32, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 32, 32, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 32, 32, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 32, 32, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 32, 32, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 32, 32, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 32, 32, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 32, 32, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 32, 32, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 32, 32, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 32, 32, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 32, 32, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 32, 32, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 32, 32, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_134 (Conv2D)            (None, 16, 16, 1024  745472      ['add_10[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 16, 16, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_134[0][0]']
#  rmalization)                   )
#
#  add_11 (Add)                   (None, 16, 16, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 16, 16, 1536  1582080    ['add_11[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 16, 16, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 16, 16, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 16, 16, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 16, 16, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 16, 16, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ## Efficient-Net V2

# %%
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M

# %%
efM = EfficientNetV2M(weights="imagenet", include_top=False, input_shape=(512, 512, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 16s 0us/step

# %%
efM.summary()
# Out:
# Model: "efficientnetv2-m"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_62 (InputLayer)          [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling_6 (Rescaling)        (None, 512, 512, 3)  0           ['input_62[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 24  648         ['rescaling_6[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 256, 256, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 256, 256, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 256, 256, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 256, 256, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 256, 256, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 256, 256, 24  5184        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 256, 256, 24  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_drop (Dropout)         (None, 256, 256, 24  0           ['block1c_project_activation[0][0
#                                 )                                ]']
#
#  block1c_add (Add)              (None, 256, 256, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 128, 128, 96  20736       ['block1c_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 128, 128, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 128, 128, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 48  4608        ['block2a_expand_activation[0][0]
#                                 )                                ']
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 128, 128, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2b_expand_activation[0][0]
#                                 )                                ']
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 128, 128, 48  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 48  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 128, 128, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2c_expand_activation[0][0]
#                                 )                                ']
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 128, 128, 48  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 48  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2c_add[0][0]']
#                                 2)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2d_expand_conv[0][0]']
#  ization)                       2)
#
#  block2d_expand_activation (Act  (None, 128, 128, 19  0          ['block2d_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2d_expand_activation[0][0]
#                                 )                                ']
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 128, 128, 48  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 48  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2d_add[0][0]']
#                                 2)
#
#  block2e_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2e_expand_conv[0][0]']
#  ization)                       2)
#
#  block2e_expand_activation (Act  (None, 128, 128, 19  0          ['block2e_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2e_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2e_expand_activation[0][0]
#                                 )                                ']
#
#  block2e_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 128, 128, 48  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 128, 128, 48  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 64, 64, 192)  82944       ['block2e_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 64, 64, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 64, 64, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 80)   15360       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 320)  230400      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 320)  1280       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 320)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 80)   25600       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 64, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 80)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 320)  230400      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 320)  1280       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 320)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 80)   25600       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 80)  320         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 64, 80)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 80)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 320)  230400      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 320)  1280       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 320)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 64, 64, 80)   25600       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 64, 64, 80)  320         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 64, 80)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 64, 80)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 64, 64, 320)  230400      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 64, 64, 320)  1280       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 64, 64, 320)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 64, 64, 80)   25600       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 64, 64, 80)  320         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_drop (Dropout)         (None, 64, 64, 80)   0           ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)              (None, 64, 64, 80)   0           ['block3e_drop[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 64, 64, 320)  25600       ['block3e_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 64, 64, 320)  1280       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 64, 64, 320)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 32, 32, 320)  2880       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 32, 32, 320)  1280       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 32, 32, 320)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 320)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 320)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 20)     6420        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 320)    6720        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 32, 32, 320)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 32, 32, 160)  51200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 32, 32, 640)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 32, 32, 640)  5760       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 32, 32, 640)  2560       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 32, 32, 640)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 640)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 32, 32, 640)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 32, 32, 160)  102400      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 32, 32, 160)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 32, 32, 160)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 32, 32, 640)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 32, 32, 640)  5760       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 32, 32, 640)  2560       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 32, 32, 640)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 640)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 32, 32, 640)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 32, 32, 160)  102400      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 32, 32, 160)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 32, 32, 160)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 32, 32, 640)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 32, 32, 640)  5760       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 32, 32, 640)  2560       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 32, 32, 640)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 640)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 32, 32, 640)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 32, 32, 160)  102400      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 32, 32, 160)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 32, 32, 160)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 32, 32, 640)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 32, 32, 640)  5760       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 32, 32, 640)  2560       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 32, 32, 640)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 640)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 32, 32, 640)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 32, 32, 160)  102400      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 32, 32, 160)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 32, 32, 160)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 32, 32, 640)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 32, 32, 640)  5760       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 32, 32, 640)  2560       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 32, 32, 640)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 640)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 32, 32, 640)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 32, 32, 160)  102400      ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 32, 32, 160)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 32, 32, 160)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block4g_expand_conv (Conv2D)   (None, 32, 32, 640)  102400      ['block4f_add[0][0]']
#
#  block4g_expand_bn (BatchNormal  (None, 32, 32, 640)  2560       ['block4g_expand_conv[0][0]']
#  ization)
#
#  block4g_expand_activation (Act  (None, 32, 32, 640)  0          ['block4g_expand_bn[0][0]']
# ...
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7b_dwconv2[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv2 (DepthwiseConv  (None, 16, 16, 3072  27648      ['block7c_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7c_dwconv2[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 16, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7c_add[0][0]']
#                                 )
#
#  block7d_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7d_expand_conv[0][0]']
#  ization)                       )
#
#  block7d_expand_activation (Act  (None, 16, 16, 3072  0          ['block7d_expand_bn[0][0]']
#  ivation)                       )
#
#  block7d_dwconv2 (DepthwiseConv  (None, 16, 16, 3072  27648      ['block7d_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7d_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7d_dwconv2[0][0]']
#  )                              )
#
#  block7d_activation (Activation  (None, 16, 16, 3072  0          ['block7d_bn[0][0]']
#  )                              )
#
#  block7d_se_squeeze (GlobalAver  (None, 3072)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7d_activation[0][0]',
#                                 )                                 'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 16, 16, 512)  0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 16, 16, 512)  0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7d_add[0][0]']
#                                 )
#
#  block7e_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7e_expand_conv[0][0]']
#  ization)                       )
#
#  block7e_expand_activation (Act  (None, 16, 16, 3072  0          ['block7e_expand_bn[0][0]']
#  ivation)                       )
#
#  block7e_dwconv2 (DepthwiseConv  (None, 16, 16, 3072  27648      ['block7e_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7e_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7e_dwconv2[0][0]']
#  )                              )
#
#  block7e_activation (Activation  (None, 16, 16, 3072  0          ['block7e_bn[0][0]']
#  )                              )
#
#  block7e_se_squeeze (GlobalAver  (None, 3072)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7e_activation[0][0]',
#                                 )                                 'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_drop (Dropout)         (None, 16, 16, 512)  0           ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)              (None, 16, 16, 512)  0           ['block7e_drop[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 1280  655360      ['block7e_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 1280  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 53,150,388
# Trainable params: 52,858,356
# Non-trainable params: 292,032
# __________________________________________________________________________________________________
